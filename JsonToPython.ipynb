# %%
import json

# %%
with open('csvjson.json')as f:
    data = f.read()

# %%
data = json.loads(data) #parse json file into python

# %%
type(data) #data is a list of dictioaries, as seen below its a list
# Out:
# list

# %%
data #pri
# Out:
# [{'DapipId': 100016,
#   'OpeId': '01230800',
#   'LocationName': 'Community College of the Air Force',
#   'ParentName': '-',
#   'ParentDapipId': '-',
#   'LocationType': 'Institution',
#   'Address': '130 W Maxwell Blvd, Montgomery, AL 36112-6613',
#   'GeneralPhone': 3349536436,
#   'AdminName': 'ERIC A. ASH',
#   'AdminPhone': 3349536436,
#   'AdminEmail': 'eric.ash@maxwell.af.mil',
#   'Fax': 3349538211,
#   'UpdateDate': ''},
#  {'DapipId': 100016002,
#   'OpeId': '',
#   'LocationName': 'Community College of the Air Force',
#   'ParentName': 'Community College of the Air Force',
#   'ParentDapipId': 100016,
#   'LocationType': 'Additional Location',
#   'Address': '2250 Stanley Road, Unit 161, Fort Sam Houston, TX 78234-6400',
#   'GeneralPhone': '',
#   'AdminName': '',
#   'AdminPhone': '',
#   'AdminEmail': '',
#   'Fax': '',
#   'UpdateDate': ''},
#  {'DapipId': 100025,
#   'OpeId': '00100200',
#   'LocationName': 'Alabama A & M University',
#   'ParentName': '-',
# ...

# %%
locNames = [i['LocationName'] for i in data] # get the location names only from the list of dictionaries

# %%
len(locNames) # you have 31,117 schools
# Out:
# 31117
